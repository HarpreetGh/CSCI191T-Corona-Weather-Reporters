# 1/2/20      0.817714  0.750229  0.722000  0.749850  0.765345  0.633747
# ...              ...       ...       ...       ...       ...       ...
# 4/8/20      0.828941  0.832127  0.935377  1.000000  0.929469  0.890267
# 4/9/20      0.933547  0.900008  0.881527  0.929469  1.000000  0.964055
# 4/10/20     0.864622  0.879516  0.869503  0.890267  0.964055  1.000000
# 4/11/20     0.862351  0.922660  0.880768  0.852827  0.936476  0.967285
# 4/12/20     0.848615  0.912243  0.909970  0.873126  0.887933  0.894714
#
#              4/11/20   4/12/20
# Unnamed: 0  0.251709  0.221223
# Lat         0.567881  0.641659
# Long        0.442844  0.351605
# 1/1/20      0.522638  0.537953
# 1/2/20      0.664284  0.696014
# ...              ...       ...
# 4/8/20      0.852827  0.873126
# 4/9/20      0.936476  0.887933
# 4/10/20     0.967285  0.894714
# 4/11/20     1.000000  0.938841
# 4/12/20     0.938841  1.000000
#
# [106 rows x 106 columns]

# %%
df['Lat'].mean() #Mean of Latitude
# Out:
# 30.37024290491118

# %%
df['Lat'].median() #Median of Latitude
# Out:
# 36.0

# %%
df['Lat'].mode() #Mode of Latitude
# Out:
# 0    36.0
# dtype: float64

# %%
df['Lat'].std() #Standard deviation of Latitude
# Out:
# 23.575548226828634

# %%
df['Lat'].var() #Variance of Latitude
# Out:
# 555.8064741955228

# %%
df['Lat'].describe() #Description of count, mean, standard deviation, min, interquartile-range, max of Latitude
# Out:
# count    29.000000
# mean     30.370243
# std      23.575548
# min     -35.675100
# 25%      21.408340
# 50%      36.000000
# 75%      46.818200
# max      63.000000
# Name: Lat, dtype: float64

# %%
df['3/14/20'].mean() #Mean of 3/14/20
# Out:
# 331.95088819226754

# %%
df['3/14/20'].median() #Median of 3/14/20
# Out:
# 324.0

# %%
df['3/14/20'].mode() #Mode of 3/14/20
# Out:
# 0    324.0
# dtype: float64

# %%
df['3/14/20'].std() #standard deviation of 3/14/20
# Out:
# 57.101485894110525

# %%
df['3/14/20'].var() #variance of 3/14/20
# Out:
# 3260.579691315303

# %%
df['3/14/20'].describe() #description of count, mean, standard deviation, min, interquartile-range, max  of 3/14/20
# Out:
# count     29.000000
# mean     331.950888
# std       57.101486
# min      251.000000
# 25%      287.000000
# 50%      324.000000
# 75%      382.000000
# max      440.000000
# Name: 3/14/20, dtype: float64

# %%
y=df['3/14/20']
x=df.Lat

# %matplotlib inline

from matplotlib import pyplot as plt

# Increase the size of the plot
plt.figure(figsize=(20,10))

# Create a scatter plot: Latitude vs 3/14/20
plt.plot(x,y, 'cx', markersize = 15)

# Add axis labels and increase the font size
plt.ylabel('Ozone', fontsize = 30)
plt.xlabel('Latitude', fontsize = 30)

# Increase the font size on the ticks on the x and y axis
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Ozone over various Latitudes on 3/14/20', fontsize = 30)
# Display the scatter plot
plt.show()

# %%
import pandas as pd 
import numpy as np 
import statistics as st
m, b = np.polyfit(x,y,1) 
print ('The slope of line is {:.2f}.'.format(m)) #Slope 
print ('The y-intercept is {:.2f}.'.format(b)) #y-intercept
print ('The best fit simple linear regression line is {:.2f}x + {:.2f}.'.format(m,b)) #Simple Linear Regression
# Out:
# The slope of line is 2.00.
# The y-intercept is 271.31.
# The best fit simple linear regression line is 2.00x + 271.31.

# %%
# %matplotlib inline

# Code Cell 9
# y coordinate for centroid
y_mean = y.mean()    
# x coordinate for centroid
x_mean = x.mean()
print ('The centroid for this dataset is x = {:.2f} and y = {:.2f}.'.format(x_mean, y_mean))
# Out:
# The centroid for this dataset is x = 30.37 and y = 331.95.

# %%
# Code Cell 10
# Create the plot inline
# %matplotlib inline
from matplotlib import pyplot as plt
# Enlarge the plot size
plt.figure(figsize=(20,10))

# Plot the scatter plot of the data set
plt.plot(x,y, 'cx', markersize = 14, label = "3/14/20") 

# Plot the centroid point
plt.plot(x_mean,y_mean, '*', markersize = 30, color = "r") 

# Plot the linear regression line
plt.plot(x, m*x + b, '-', label = 'Simple Linear Regression Line', linewidth = 4)

# Create the x and y axis labels
plt.ylabel('Ozone', fontsize = 30)
plt.xlabel('Latitude', fontsize = 30)

# Enlarge x and y tick marks
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# Point out the centroid point in the plot
plt.annotate('Centroid', xy=(x_mean-0.1, y_mean-5), xytext=(x_mean-3, y_mean-20), arrowprops=dict(facecolor='black', shrink=0.05), fontsize = 30)
plt.title('Ozone over various Latitudes on 3/14/20', fontsize = 30)
# Create legend
plt.legend(loc = 'upper right', fontsize = 20)

# %%
#Predict ozone level of latitude of countries greater than 20 on 3/14/20
def predict(query):
    if query >= 1:
        predict = m * query + b
        return predict
    else:
        print ("You must predict ozone level of latitude of countries greater than 20 at 3/14/20.")

# %%
predict(20)
# Out:
# 311.24599972607757

# %%
import numpy as np
import pandas as pd 
df = pd.read_csv("./ozoneFinal.csv");
df.head(107)
# Out:
#     Unnamed: 0 Country/Region        Lat        Long      1/1/20      1/2/20  \
# 0            0        Austria  47.516200   14.550100  319.000000  318.000000
# 1            1        Belgium  50.833300    4.000000  305.000000  330.000000
# 2            2         Brazil -14.235000  -51.925300  261.000000  260.000000
# 3            3          Chile -35.675100  -71.543000  263.000000  262.000000
# 4            4        Ecuador  -1.831200  -78.183400  230.000000  230.000000
# 5            5        Germany  51.000000    9.000000  294.000000  329.000000
# 6            6          India  21.000000   78.000000  257.000000  263.000000
# 7            7           Iran  32.000000   53.000000  311.000000  294.000000
# 8            8        Ireland  53.142400   -7.692100  296.000000  312.000000
# 9            9         Israel  31.000000   35.000000  286.000000  297.000000
# 10          10          Italy  43.000000   12.000000  327.000000  342.000000
# 11          11          Japan  36.000000  138.000000  308.000000  314.000000
# 12          12       Pakistan  30.375300   69.345100  366.000000  331.000000
# 13          13           Peru  -9.190000  -75.015200  245.000000  245.000000
# 14          14         Poland  51.919400   19.145100  311.000000  326.000000
# 15          15       Portugal  39.399900   -8.224500  298.000000  303.000000
# 16          16         Russia  60.000000   90.000000  274.000000  309.000000
# 17          17   Saudi Arabia  24.000000   45.000000  252.000000  249.000000
# 18          18      Singapore   1.283300  103.833300  247.000000  249.000000
# 19          19          Spain  40.000000   -4.000000  298.000000  300.000000
# 20          20         Sweden  63.000000   16.000000  255.000000  251.000000
# 21          21    Switzerland  46.818200    8.227500  320.000000  324.000000
# 10  391.000000  375.000000  341.000000  317.000000  328.000000  349.000000
# 11  361.000000  367.000000  365.000000  351.000000  356.000000  368.000000
# 12  310.000000  312.000000  317.000000  328.000000  312.000000  308.000000
# 13  248.000000  249.000000  250.000000  249.000000  247.000000  250.000000
# 14  345.000000  325.000000  299.000000  296.000000  332.000000  342.000000
# 15  341.000000  337.000000  341.000000  329.000000  312.000000  310.000000
# 16  381.000000  369.000000  389.000000  373.000000  358.000000  386.000000
# 17  289.000000  288.000000  283.000000  282.000000  285.000000  285.000000
# 18  254.000000  258.000000  257.000000  258.000000  257.000000  258.000000
# 19  340.000000  340.000000  335.000000  336.000000  320.000000  314.000000
# 20  292.000000  247.000000  258.000000  320.000000  338.000000  283.000000
# 21  358.000000  327.000000  304.000000  305.000000  330.000000  319.000000
# 22  381.000000  363.000000  363.000000  352.000000  364.000000  368.000000
# 23  366.000000  372.000000  361.000000  368.000000  379.000000  385.000000
# 24  323.000000  338.000000  327.000000  321.000000  309.000000  317.000000
# 25  327.939394  329.878788  335.181818  336.878788  339.787879  341.696970
# 26  377.533333  387.666667  387.866667  402.000000  400.266667  386.600000
# 27  280.000000  279.000000  280.454545  283.090909  286.272727  281.636364
# 28  279.000000  272.200000  271.400000  278.400000  275.800000  272.400000
#
#        4/10/20     4/11/20     4/12/20
# 0   311.000000  300.000000  322.000000
# 1   295.000000  313.000000  338.000000
# 2   257.000000  257.000000  255.000000
# 3   257.000000  264.000000  276.000000
# 4   248.000000  249.000000  247.000000
# 5   308.000000  311.000000  328.000000
# 6   289.000000  294.000000  292.000000
# 7   300.000000  307.000000  322.000000
# 8   309.000000  330.000000  366.000000
# 9   348.000000  350.000000  351.000000
# 10  320.000000  301.000000  311.000000
# 11  397.000000  397.000000  375.000000
# 12  310.000000  302.000000  295.000000
# 13  254.000000  250.000000  252.000000
# 14  332.000000  330.000000  313.000000
# 15  306.000000  331.000000  359.000000
# 16  389.000000  400.000000  373.000000
# 17  281.000000  279.000000  282.000000
# 18  258.000000  258.000000  260.000000
# 19  304.000000  311.000000  333.000000
# 20  287.000000  257.000000  275.000000
# 21  302.000000  296.000000  329.000000
# 22  344.000000  359.000000  346.000000
# 23  400.000000  392.000000  408.000000
# 24  308.000000  322.000000  324.000000
# 25  341.090909  344.060606  341.303030
# 26  379.400000  388.666667  398.466667
# 27  277.545455  280.363636  287.727273
# 28  270.600000  274.400000  279.400000
#
# [29 rows x 107 columns]

# %%
df['Lat'].mean() #Mean of Latitude
# Out:
# 30.37024290491118

# %%
df['Lat'].median() #Median of Latitude
# Out:
# 36.0

# %%
df['Lat'].mode() #Mode of Latitude
# Out:
# 0    36.0
# dtype: float64

# %%
df['Lat'].std() #Standard deviation of Latitude
# Out:
# 23.575548226828634

# %%
df['Lat'].var() #Variance of Latitude
# Out:
# 555.8064741955228

# %%
df['Lat'].describe() #Description of count, mean, standard deviation, min, interquartile-range, max of Latitude
# Out:
# count    29.000000
# mean     30.370243
# std      23.575548
# min     -35.675100
# 25%      21.408340
# 50%      36.000000
# 75%      46.818200
# max      63.000000
# Name: Lat, dtype: float64

# %%
df['2/6/20'].mean() #Mean of 2/6/20
# Out:
# 308.90595611285266

# %%
df['2/6/20'].median() #Median of 2/6/20
# Out:
# 313.0

# %%
df['2/6/20'].mode() #Mode of 2/6/20
# Out:
# 0    354.0
# dtype: float64

# %%
df['2/6/20'].std() #Standard deviation of 2/6/20
# Out:
# 37.52149830641857

# %%
df['2/6/20'].var() #Variance of 2/6/20
# Out:
# 1407.8628351585717

# %%
df['2/6/20'].describe() #Description of count, mean, standard deviation, min, interquartile-range, max of 3/14/20
# Out:
# count     29.000000
# mean     308.905956
# std       37.521498
# min      246.000000
# 25%      281.000000
# 50%      313.000000
# 75%      336.000000
# max      372.400000
# Name: 2/6/20, dtype: float64

# %%
#this looks good but remember about the dates, probably average them to use the data
y=df['2/6/20']
x=df.Lat

# %matplotlib inline

from matplotlib import pyplot as plt

# Increase the size of the plot
plt.figure(figsize=(20,10))

# Create a scatter plot: Latitude vs 2/6/20
plt.plot(x,y, 'cx', markersize = 15)

# Add axis labels and increase the font size
plt.ylabel('Ozone', fontsize = 30)
plt.xlabel('Latitude', fontsize = 30)

# Increase the font size on the ticks on the x and y axis
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Ozone over various Latitudes on 2/6/20', fontsize = 30)
# Display the scatter plot
plt.show()

# %%
# %matplotlib inline
#Code Cell 9
import pandas as pd 
import numpy as np 
import statistics as st
m, b = np.polyfit(x,y,1) 
print ('The slope of line is {:.2f}.'.format(m)) #Slope 
print ('The y-intercept is {:.2f}.'.format(b)) #y-intercept
print ('The best fit simple linear regression line is {:.2f}x + {:.2f}.'.format(m,b)) #Simple Linear Regression
# y coordinate for centroid
y_mean = y.mean()    
# x coordinate for centroid
x_mean = x.mean()
print ('The centroid for this dataset is x = {:.2f} and y = {:.2f}.'.format(x_mean, y_mean))
# Out:
# The slope of line is 1.17.
# The y-intercept is 273.26.
# The best fit simple linear regression line is 1.17x + 273.26.
# The centroid for this dataset is x = 30.37 and y = 308.91.

# %%
#same as previous comment
# Code Cell 10
# Create the plot inline
# %matplotlib inline
from matplotlib import pyplot as plt
# Enlarge the plot size
plt.figure(figsize=(20,10))

# Plot the scatter plot of the data set
plt.plot(x,y, 'cx', markersize = 14, label = "2/6/20") 

# Plot the centroid point
plt.plot(x_mean,y_mean, '*', markersize = 30, color = "r") 

# Plot the linear regression line
plt.plot(x, m*x + b, '-', label = 'Simple Linear Regression Line', linewidth = 4)

# Create the x and y axis labels
plt.ylabel('Ozone', fontsize = 30)
plt.xlabel('Latitude', fontsize = 30)

# Enlarge x and y tick marks
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# Point out the centroid point in the plot
plt.annotate('Centroid', xy=(x_mean-0.1, y_mean-5), xytext=(x_mean-3, y_mean-20), arrowprops=dict(facecolor='black', shrink=0.05), fontsize = 30)
plt.title('Ozone over various Latitudes on 2/6/20', fontsize = 30)
# Create legend
plt.legend(loc = 'upper right', fontsize = 20)

# %%
#Predict ozone level of latitude of countries greater than 20 on 2/6/20
def predict(query):
    if query >= 1:
        predict = m * query + b
        return predict
    else:
        print ("You must predict ozone level of latitude of countries greater than 20 at 2/6/20.")

# %%
predict(30)
# Out:
# 308.4714134327054
